# %% [markdown]
# ## Python Mini Project

# %% [markdown]
# ### Write the python code for ATM
# ### (Automated Teller Machine)

# %% [markdown]
# When creating the ATM program, the class objects are
# created under a class and these objects have variables
# with an associated behaviour. For instance, when
# depositing funds into an account, the balance will
# increase and with withdraw of funds the balance will
# decrease but never go below a fund of amount of $0.00.
# 1. Input 4 digit user pin for authentication
# 2. You have to input user pin double times and check
# whether they are equal
# 3. If pin is found okay, ask for the input selection of
# numbers from 1 to 4
# 4. If selection is 1, Check saving balance and print the
# balance
# 5. If selection is 2, Deposit funds from the user and
# print the saving balance after deposit
# 6. If selection is 3, Withdraw funds from the savings
# balance account and print the balance after
# withdrawal
# 7. If selection is 4, Transfer funds from checking
# balance to savings balance.
# For this, you have to initially create the variable for checking balance
# and assign some amount to that variable. If
# selection 4 is made, the amount from checking
# balance must be debited and credited to saving
# account. Then, you have to print the balance in
# checking balance and saving balance.
# 8. If selection is other than 1 to 4, print invalid choice
# and exit the loop.

# %% [markdown]
# ### Code

# %%
import random
import sys
 
class ATM():
    def __init__(self, account_pin, balance = 0):
        self.account_pin = account_pin
        self.balance = balance
         
    def account_detail(self):
        print("\n----------ACCOUNT DETAIL----------")
        print(f"Available balance: {self.balance}\n")
         
    def deposit(self, amount):
        self.amount = amount
        self.balance = self.balance + self.amount
        print("Current account balance: ", self.balance)
        print()
 
    def withdraw(self, amount):
        self.amount = amount
        if self.amount > self.balance:
            print("Insufficient fund!")
            print(f"Your balance is {self.balance} only.")
            print("Try with lesser amount than balance.")
            print()
        else:
            self.balance = self.balance - self.amount
            print(f"{amount} withdrawal successful!")
            print("Current account balance: ", self.balance)
            print()
 
    def check_balance(self):
        print("Available balance: ", self.balance)
        print()
 
    def transaction(self):
        print("""
        
     ---------------------------------------
    |                                        |
    |                                        |
    |            TRANSACTION MENU:           |
    |      **************************        |
    |        1. Account Detail               |
    |        2. Check Balance                |
    |        3. Deposit                      |
    |        4. Withdraw                     |
    |        5. Exit                         |
    |      **************************        |
    |                                        |
     ----------------------------------------   
       
       """)
        
        while True:
            try:
                option = int(input("Enter 1, 2, 3, 4 or 5:"))
                print()
            except:
                print("Error: Enter 1, 2, 3, 4, or 5 only!\n")
                print()
                continue
            else:
                if option == 1:
                    atm.account_detail()
                elif option == 2:
                    atm.check_balance()
                elif option == 3:
                    amount = int(input("How much you want to deposit:"))
                    print()
                    atm.deposit(amount)
                elif option == 4:
                    amount = int(input("How much you want to withdraw:"))
                    print()
                    atm.withdraw(amount)
                elif option == 5:
                    print(f"""
          -----------------------------------------
                  Transaction is now complete
          -----------------------------------------
                    
                  printing receipt..............
                  
          ******************************************
          
              Transaction is now complete.                         
              Transaction number: {random.randint(10000, 1000000)}                 
              Available balance: {self.balance}                    
 
              Thanks for choosing us as your bank  
              
          ******************************************
          """)
                    sys.exit()
                    
                 
 
print("""   
        ------------------------------------------
       |                                          |
       |         ********WELCOME******            |
       |                                          |
        ------------------------------------------ 
    """)
               
print()
print("___________________________________________________________\n")
print()
print("----------ACCOUNT VALIDATION----------")
print()
account_pin = input("Enter your account pin: ")
account_pin1 = input("Enter your account pin again: ")

if account_pin!=account_pin1:
    print("Session failed-- Mismatch account pin")
    
else:
    print()
    print("Congratulations! Logged in successfully......\n")
    print()
    atm = ATM(account_pin)
 
    while True:
        trans = input("Do you want to do any transaction?(y/n):")
        if trans == "y":
            atm.transaction()
        elif trans == "n":
            print("""
        -------------------------------------
       | Thanks for choosing us as your bank |
       |           Visit us again!           |
        -------------------------------------
            """)
            break
        else:
            print("Wrong command!  Enter 'y' for YES and 'n' for NO.\n")
# Out:
#
#         ------------------------------------------
#        |                                          |
#        |         ********WELCOME******            |
#        |                                          |
#         ------------------------------------------
#
#
# ___________________________________________________________
#
#
# ----------ACCOUNT VALIDATION----------
#
# Enter your account pin: 6734
# Enter your account pin again: 6734
#
# Congratulations! Logged in successfully......
#
#
# Do you want to do any transaction?(y/n):y
#
#
#      ---------------------------------------
#     |                                        |
#     |                                        |
#     |            TRANSACTION MENU:           |
#     |      **************************        |
#     |        1. Account Detail               |
#     |        2. Check Balance                |
#     |        3. Deposit                      |
#     |        4. Withdraw                     |
# ...
